# %% [markdown]
# # Melhor forma de usar pivot e groupby()

# %%
import pandas as pd

# %%
drinks = pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks.head()
# Out:
#        country  beer_servings  ...  total_litres_of_pure_alcohol  continent
# 0  Afghanistan              0  ...                           0.0       Asia
# 1      Albania             89  ...                           4.9     Europe
# 2      Algeria             25  ...                           0.7     Africa
# 3      Andorra            245  ...                          12.4     Europe
# 4       Angola            217  ...                           5.9     Africa
#
# [5 rows x 6 columns]

# %%
drinks.groupby('continent').beer_servings.mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
drinks.groupby('continent').beer_servings.max()
# Out:
# continent
# Africa           376
# Asia             247
# Europe           361
# North America    285
# Oceania          306
# South America    333
# Name: beer_servings, dtype: int64

# %%
drinks.groupby('continent').beer_servings.agg(['max','mean','min'])
# Out:
#                max        mean  min
# continent
# Africa         376   61.471698    0
# Asia           247   37.045455    0
# Europe         361  193.777778    0
# North America  285  145.434783    1
# Oceania        306   89.687500    0
# South America  333  175.083333   93

# %%
df = pd.DataFrame({'name':['A','A','B','B'], 'day':[1,2,1,2],'weight':[100,103,130,129], 'height':[67,68,72,72]})

# %%
df
# Out:
#   name  day  weight  height
# 0    A    1     100      67
# 1    A    2     103      68
# 2    B    1     130      72
# 3    B    2     129      72

# %%
df.set_index(['name','day'])
# Out:
#           weight  height
# name day
# A    1       100      67
#      2       103      68
# B    1       130      72
#      2       129      72

# %%
df.set_index(['name','day']).to_panel()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-f9e7b0f6d664> in <module>()
# ----> 1 df.set_index(['name','day']).to_panel()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'to_panel'
