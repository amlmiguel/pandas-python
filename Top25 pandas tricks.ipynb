# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #Mostrar as versões instaladas

# %%
pd.__version__
# Out:
# '1.0.5'

# %%
pd.show_versions()
# Out:
# /usr/local/lib/python3.6/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal
# INSTALLED VERSIONS
# ------------------
# commit           : None
# python           : 3.6.9.final.0
# python-bits      : 64
# OS               : Linux
# OS-release       : 4.19.104+
# machine          : x86_64
# processor        : x86_64
# byteorder        : little
# LC_ALL           : None
# LANG             : en_US.UTF-8
# LOCALE           : en_US.UTF-8
#
# pandas           : 1.0.5
# numpy            : 1.18.5
# ...

# %% [markdown]
# # Criando um dataframe para exemplo

# %%
df = pd.DataFrame({'col one':[100,200],'col two':[300,400]})

# %%
df
# Out:
#    col one  col two
# 0      100      300
# 1      200      400

# %%
pd.DataFrame(np.random.rand(4,8))
# Out:
#           0         1         2  ...         5         6         7
# 0  0.384452  0.724115  0.584806  ...  0.228655  0.696914  0.992075
# 1  0.110453  0.609818  0.245999  ...  0.255722  0.722998  0.161828
# 2  0.769063  0.362888  0.987792  ...  0.568981  0.288736  0.622442
# 3  0.084086  0.836599  0.079585  ...  0.824413  0.383891  0.833540
#
# [4 rows x 8 columns]

# %%
pd.DataFrame(np.random.rand(4,8), columns=list('abcdefgh'))
# Out:
#           a         b         c  ...         f         g         h
# 0  0.308826  0.173858  0.493040  ...  0.701129  0.495967  0.985009
# 1  0.517408  0.897304  0.091964  ...  0.137056  0.938777  0.157653
# 2  0.576010  0.867214  0.661246  ...  0.890333  0.403599  0.002240
# 3  0.426598  0.100554  0.548223  ...  0.992208  0.923698  0.287853
#
# [4 rows x 8 columns]

# %% [markdown]
# # Renomeando Colunas

# %%
df
# Out:
#    col one  col two
# 0      100      300
# 1      200      400

# %%
df = df.rename({'col one':'col_one', 'col two':'col_two'}, axis = 'columns')
df
# Out:
#    col_one  col_two
# 0      100      300
# 1      200      400

# %%
df.columns = ['col_1','col_2']
df
# Out:
#    col_1  col_2
# 0    100    300
# 1    200    400

# %%
df.columns = df.columns.str.replace('_', ' ')
df
# Out:
#    col 1  col 2
# 0    100    300
# 1    200    400

# %%
df.add_prefix('x_')
# Out:
#    x_col 1  x_col 2
# 0      100      300
# 1      200      400

# %%
df.add_suffix('_x')
# Out:
#    col 1_x  col 2_x
# 0      100      300
# 1      200      400

# %% [markdown]
# # Ordem Reversa

# %%
drinks = pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks.head()
# Out:
#        country  beer_servings  ...  total_litres_of_pure_alcohol  continent
# 0  Afghanistan              0  ...                           0.0       Asia
# 1      Albania             89  ...                           4.9     Europe
# 2      Algeria             25  ...                           0.7     Africa
# 3      Andorra            245  ...                          12.4     Europe
# 4       Angola            217  ...                           5.9     Africa
#
# [5 rows x 6 columns]

# %%
drinks.loc[::-1].head()
# Out:
#        country  beer_servings  ...  total_litres_of_pure_alcohol      continent
# 192   Zimbabwe             64  ...                           4.7         Africa
# 191     Zambia             32  ...                           2.5         Africa
# 190      Yemen              6  ...                           0.1           Asia
# 189    Vietnam            111  ...                           2.0           Asia
# 188  Venezuela            333  ...                           7.7  South America
#
# [5 rows x 6 columns]

# %%
drinks.loc[::-1].reset_index(drop = True).head()
# Out:
#      country  beer_servings  ...  total_litres_of_pure_alcohol      continent
# 0   Zimbabwe             64  ...                           4.7         Africa
# 1     Zambia             32  ...                           2.5         Africa
# 2      Yemen              6  ...                           0.1           Asia
# 3    Vietnam            111  ...                           2.0           Asia
# 4  Venezuela            333  ...                           7.7  South America
#
# [5 rows x 6 columns]

# %% [markdown]
# # Revertendo a ordem das colunas

# %%
drinks.loc[:,::-1].head()
# Out:
#   continent  total_litres_of_pure_alcohol  ...  beer_servings      country
# 0      Asia                           0.0  ...              0  Afghanistan
# 1    Europe                           4.9  ...             89      Albania
# 2    Africa                           0.7  ...             25      Algeria
# 3    Europe                          12.4  ...            245      Andorra
# 4    Africa                           5.9  ...            217       Angola
#
# [5 rows x 6 columns]

# %% [markdown]
# # Selecionando colunas pelos tipos de dados

# %%
drinks.select_dtypes(include='number').head() # Esse argumento incluirá inteiros e floats
# Out:
#    beer_servings  spirit_servings  wine_servings  total_litres_of_pure_alcohol
# 0              0                0              0                           0.0
# 1             89              132             54                           4.9
# 2             25                0             14                           0.7
# 3            245              138            312                          12.4
# 4            217               57             45                           5.9

# %%
drinks.select_dtypes(include = 'object').head()
# Out:
#        country continent
# 0  Afghanistan      Asia
# 1      Albania    Europe
# 2      Algeria    Africa
# 3      Andorra    Europe
# 4       Angola    Africa

# %%
drinks.select_dtypes(include=['number', 'object', 'category', 'datetime']).head()
# Out:
#        country  beer_servings  ...  total_litres_of_pure_alcohol  continent
# 0  Afghanistan              0  ...                           0.0       Asia
# 1      Albania             89  ...                           4.9     Europe
# 2      Algeria             25  ...                           0.7     Africa
# 3      Andorra            245  ...                          12.4     Europe
# 4       Angola            217  ...                           5.9     Africa
#
# [5 rows x 6 columns]

# %%
drinks.select_dtypes(exclude = 'number').head()
# Out:
#        country continent
# 0  Afghanistan      Asia
# 1      Albania    Europe
# 2      Algeria    Africa
# 3      Andorra    Europe
# 4       Angola    Africa

# %% [markdown]
# # Converter String para número

# %%
df = pd.DataFrame({'col_one':['1.1', '2.2', '3.3'],
                   'col_two':['4.4', '5.5', '6.6'],
                   'col_three':['7.7', '8.8', '-']})
df
# Out:
#   col_one col_two col_three
# 0     1.1     4.4       7.7
# 1     2.2     5.5       8.8
# 2     3.3     6.6         -

# %%
df.dtypes
# Out:
# col_one      object
# col_two      object
# col_three    object
# dtype: object

# %%
df.astype({'col_one':'float','col_two':'float'}).dtypes
# Out:
# col_one      float64
# col_two      float64
# col_three     object
# dtype: object

# %% [markdown]
# Entretanto, se tentarmos incluir a tereira coluna nesse esquema teríamos um erro. Isso porque a terceira coluna na terceria linha é um hífen, e o pandas não sabe como interpreta-lo
#
# Ao ínves disso, podemos usar to_numeric() e explicitar apra converter um caracter invalido para NaN

# %%
pd.to_numeric(df.col_three,errors='coerce')
# Out:
# 0    7.7
# 1    8.8
# 2    NaN
# Name: col_three, dtype: float64

# %%
pd.to_numeric(df.col_three, errors='coerce').fillna(0)
# Out:
# 0    7.7
# 1    8.8
# 2    0.0
# Name: col_three, dtype: float64

# %% [markdown]
# Para aplicar isso em todo data frame usamos o apply()

# %%
df = df.apply(pd.to_numeric, errors='coerce').fillna(0)
df
# Out:
#    col_one  col_two  col_three
# 0      1.1      4.4        7.7
# 1      2.2      5.5        8.8
# 2      3.3      6.6        0.0

# %%
df.dtypes
# Out:
# col_one      float64
# col_two      float64
# col_three    float64
# dtype: object

# %% [markdown]
# # Construindo um data frame atravé de multiplos arquivos

# %%
stocks = pd.read_csv('http://bit.ly/smallstocks', parse_dates=['Date'])
